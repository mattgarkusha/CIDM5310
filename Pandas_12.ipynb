# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read in data

# %%
household_elec = pd.read_csv('sample_data/household_power_consumption.csv', sep = ';', low_memory = False)
household_elec.head()
# Out:
#        Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  1/8/2008  00:00:00               0.500                 0.226  239.750
# 1  1/8/2008  00:01:00               0.482                 0.224  240.340
# 2  1/8/2008  00:02:00               0.502                 0.234  241.680
# 3  1/8/2008  00:03:00               0.556                 0.228  241.750
# 4  1/8/2008  00:04:00               0.854                 0.342  241.550
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0            2.400          0.000          0.000             1.0
# 1            2.200          0.000          0.000             1.0
# 2            2.400          0.000          0.000             0.0
# 3            2.600          0.000          0.000             1.0
# 4            4.000          0.000          1.000             7.0

# %% [markdown]
# # Fix some data

# %%
household_elec.dtypes
# Out:
# Date                      object
# Time                      object
# Global_active_power       object
# Global_reactive_power     object
# Voltage                   object
# Global_intensity          object
# Sub_metering_1            object
# Sub_metering_2            object
# Sub_metering_3           float64
# dtype: object

# %%
household_elec.replace('?', np.nan, inplace = True)
household_elec.interpolate(inplace = True)
for col in household_elec.columns[2:]:
  household_elec[col] = household_elec[col].astype(float)

# %% [markdown]
# # Visualization

# %%
(household_elec[['Date', 'Sub_metering_1']].plot(x = 'Date', y = 'Sub_metering_1'))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Cleanup

# %%
kitchen_elec = household_elec[['Date', 'Time', 'Sub_metering_1']]
kitchen_elec = kitchen_elec.loc[kitchen_elec['Date'].str.contains('2009'), :]
kitchen_elec.columns = ['Date','Time', 'Kitchen_power_use']
kitchen_elec.head()
# Out:
#             Date      Time  Kitchen_power_use
# 220320  1/1/2009  00:00:00                0.0
# 220321  1/1/2009  00:01:00                0.0
# 220322  1/1/2009  00:02:00                0.0
# 220323  1/1/2009  00:03:00                0.0
# 220324  1/1/2009  00:04:00                0.0

# %%
kitchen_elec.loc[:, 'timestamp'] = pd.to_datetime(kitchen_elec.loc[:, 'Date'] + ' ' + kitchen_elec.loc[:, 'Time'], dayfirst = True)
kitchen_elec.sort_values('timestamp', inplace = True)
kitchen_elec.head()
# Out:
#             Date      Time  Kitchen_power_use           timestamp
# 220320  1/1/2009  00:00:00                0.0 2009-01-01 00:00:00
# 220321  1/1/2009  00:01:00                0.0 2009-01-01 00:01:00
# 220322  1/1/2009  00:02:00                0.0 2009-01-01 00:02:00
# 220323  1/1/2009  00:03:00                0.0 2009-01-01 00:03:00
# 220324  1/1/2009  00:04:00                0.0 2009-01-01 00:04:00

# %%
kitchen_elec['hour'] = kitchen_elec['timestamp'].dt.hour
kitchen_elec['date'] = kitchen_elec['timestamp'].dt.date
kitchen_elec.head()
# Out:
#             Date      Time  Kitchen_power_use           timestamp  hour  \
# 220320  1/1/2009  00:00:00                0.0 2009-01-01 00:00:00     0
# 220321  1/1/2009  00:01:00                0.0 2009-01-01 00:01:00     0
# 220322  1/1/2009  00:02:00                0.0 2009-01-01 00:02:00     0
# 220323  1/1/2009  00:03:00                0.0 2009-01-01 00:03:00     0
# 220324  1/1/2009  00:04:00                0.0 2009-01-01 00:04:00     0
#
#               date
# 220320  2009-01-01
# 220321  2009-01-01
# 220322  2009-01-01
# 220323  2009-01-01
# 220324  2009-01-01

# %%
kitchen_elec = kitchen_elec[['date','hour', 'Kitchen_power_use']].groupby(['date', 'hour']).sum()
kitchen_elec.reset_index(inplace = True)
kitchen_elec.iloc[20:28, :]
# Out:
#           date  hour  Kitchen_power_use
# 20  2009-01-01    20                0.0
# 21  2009-01-01    21                0.0
# 22  2009-01-01    22                0.0
# 23  2009-01-01    23                0.0
# 24  2009-01-02     0                0.0
# 25  2009-01-02     1                0.0
# 26  2009-01-02     2                0.0
# 27  2009-01-02     3                0.0

# %% [markdown]
# # Visualization

# %%
(kitchen_elec.loc[((kitchen_elec['date'] >=
                    pd.to_datetime('2009-01-01')) &
                   (kitchen_elec['date'] <
                    pd.to_datetime('2009-02-01'))),
['hour', 'Kitchen_power_use']].groupby('hour').mean().plot(kind = 'bar'))
# Out:
# <ipython-input-19-aa2bb16a374b>:1: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   (kitchen_elec.loc[((kitchen_elec['date'] >=
# <ipython-input-19-aa2bb16a374b>:3: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   (kitchen_elec['date'] <
# <Axes: xlabel='hour'>

# %%
(kitchen_elec.loc[:, ['hour', 'Kitchen_power_use']].groupby('hour').mean().plot(kind = 'bar'))
# Out:
# <Axes: xlabel='hour'>
